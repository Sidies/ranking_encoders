# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../../../reports/best_scores.csv')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data)
# Out:
#                            approach  tuning            metric   score  fold
# 0                        regression     NaN  average_spearman  0.5887     1
# 1                        regression     NaN  average_spearman  0.5847     2
# 2                        regression     NaN  average_spearman  0.5553     3
# 3                        regression     NaN  average_spearman  0.5808     4
# 4                        regression     NaN  average_spearman  0.5895     5
# 5                        regression   bayes  average_spearman  0.5776     1
# 6                        regression   bayes  average_spearman  0.5834     2
# 7                        regression   bayes  average_spearman  0.5692     3
# 8                        regression   bayes  average_spearman  0.5734     4
# 9                        regression   bayes  average_spearman  0.5706     5
# 10  pointwise_normalized_regression     NaN  average_spearman  0.7308     1
# 11  pointwise_normalized_regression     NaN  average_spearman  0.7019     2
# 12  pointwise_normalized_regression     NaN  average_spearman  0.6765     3
# 13  pointwise_normalized_regression     NaN  average_spearman  0.7076     4
# 14  pointwise_normalized_regression     NaN  average_spearman  0.7003     5
# 15  pointwise_normalized_regression   bayes  average_spearman  0.7394     1
# 16  pointwise_normalized_regression   bayes  average_spearman  0.7193     2
# 17  pointwise_normalized_regression   bayes  average_spearman  0.6917     3
# 18  pointwise_normalized_regression   bayes  average_spearman  0.7182     4
# 19  pointwise_normalized_regression   bayes  average_spearman  0.7164     5
# 20         pointwise_classification     NaN  average_spearman  0.6486     1
# 21         pointwise_classification     NaN  average_spearman  0.6103     2
# 22         pointwise_classification     NaN  average_spearman  0.6211     3
# 23         pointwise_classification     NaN  average_spearman  0.6254     4
# 24         pointwise_classification     NaN  average_spearman  0.6360     5
# 25         pointwise_classification   bayes  average_spearman  0.6463     1
# 26         pointwise_classification   bayes  average_spearman  0.6021     2
# 27         pointwise_classification   bayes  average_spearman  0.6093     3
# 28         pointwise_classification   bayes  average_spearman  0.6285     4
# 29         pointwise_classification   bayes  average_spearman  0.6012     5
# 30     pointwise_ordinal_regression     NaN  average_spearman  0.6389     1
# 31     pointwise_ordinal_regression     NaN  average_spearman  0.6491     2
# 32     pointwise_ordinal_regression     NaN  average_spearman  0.6231     3
# 33     pointwise_ordinal_regression     NaN  average_spearman  0.6637     4
# 34     pointwise_ordinal_regression     NaN  average_spearman  0.6365     5
# 35     pointwise_ordinal_regression   bayes  average_spearman  0.6598     1
# 36     pointwise_ordinal_regression   bayes  average_spearman  0.6491     2
# 37     pointwise_ordinal_regression   bayes  average_spearman  0.6123     3
# 38     pointwise_ordinal_regression   bayes  average_spearman  0.6552     4
# 39     pointwise_ordinal_regression   bayes  average_spearman  0.6520     5
# 40          pairwise_classification     NaN  average_spearman  0.7178     1
# 41          pairwise_classification     NaN  average_spearman  0.7219     2
# 42          pairwise_classification     NaN  average_spearman  0.7204     3
# 43          pairwise_classification     NaN  average_spearman  0.7164     4
# 44          pairwise_classification     NaN  average_spearman  0.7218     5
# 45          pairwise_classification  optuna  average_spearman  0.7226     1
# 46          pairwise_classification  optuna  average_spearman  0.7238     2
# 47          pairwise_classification  optuna  average_spearman  0.7116     3
# 48          pairwise_classification  optuna  average_spearman  0.7320     4
# 49          pairwise_classification  optuna  average_spearman  0.7247     5
# 50              listwise_regression     NaN  average_spearman  0.7693     1
# 51              listwise_regression     NaN  average_spearman  0.7382     2
# 52              listwise_regression     NaN  average_spearman  0.7188     3
# 53              listwise_regression     NaN  average_spearman  0.7493     4
# 54              listwise_regression     NaN  average_spearman  0.7273     5
# 55              listwise_regression   bayes  average_spearman  0.7223     1
# 56              listwise_regression   bayes  average_spearman  0.6940     2
# 57              listwise_regression   bayes  average_spearman  0.7307     3
# 58              listwise_regression   bayes  average_spearman  0.7466     4
# 59              listwise_regression   bayes  average_spearman  0.7167     5
# 60          listwise_neural_network     NaN  average_spearman  0.1504     1
# 61          listwise_neural_network     NaN  average_spearman  0.1739     2
# 62          listwise_neural_network     NaN  average_spearman  0.1246     3
# 63          listwise_neural_network     NaN  average_spearman  0.1511     4
# 64          listwise_neural_network     NaN  average_spearman  0.1319     5
# 65          listwise_neural_network     NaN              ndcg  0.6524     1
# 66          listwise_neural_network     NaN              ndcg  0.6985     2
# 67          listwise_neural_network     NaN              ndcg  0.6875     3
# 68          listwise_neural_network     NaN              ndcg  0.6890     4
# 69          listwise_neural_network     NaN              ndcg  0.6790     5

# %%
string_map = {
    'pointwise_normalized_regression': 'ptw. regression',
    'pointwise_classification': 'ptw. classification',
    'pointwise_ordinal_regression': 'ptw. ord. regression',
    'pairwise_classification': 'pw. classification',
    'listwise_regression': 'lstw. regression',
    'listwise_neural_network': 'lstw. neural network',
    'average_spearman': 'avg. spearman'
}

data = data.replace(string_map)

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data)
# Out:
#                 approach  tuning         metric   score  fold
# 0             regression     NaN  avg. spearman  0.5887     1
# 1             regression     NaN  avg. spearman  0.5847     2
# 2             regression     NaN  avg. spearman  0.5553     3
# 3             regression     NaN  avg. spearman  0.5808     4
# 4             regression     NaN  avg. spearman  0.5895     5
# 5             regression   bayes  avg. spearman  0.5776     1
# 6             regression   bayes  avg. spearman  0.5834     2
# 7             regression   bayes  avg. spearman  0.5692     3
# 8             regression   bayes  avg. spearman  0.5734     4
# 9             regression   bayes  avg. spearman  0.5706     5
# 10       ptw. regression     NaN  avg. spearman  0.7308     1
# 11       ptw. regression     NaN  avg. spearman  0.7019     2
# 12       ptw. regression     NaN  avg. spearman  0.6765     3
# 13       ptw. regression     NaN  avg. spearman  0.7076     4
# 14       ptw. regression     NaN  avg. spearman  0.7003     5
# 15       ptw. regression   bayes  avg. spearman  0.7394     1
# 16       ptw. regression   bayes  avg. spearman  0.7193     2
# 17       ptw. regression   bayes  avg. spearman  0.6917     3
# 18       ptw. regression   bayes  avg. spearman  0.7182     4
# 19       ptw. regression   bayes  avg. spearman  0.7164     5
# 20   ptw. classification     NaN  avg. spearman  0.6486     1
# 21   ptw. classification     NaN  avg. spearman  0.6103     2
# 22   ptw. classification     NaN  avg. spearman  0.6211     3
# 23   ptw. classification     NaN  avg. spearman  0.6254     4
# 24   ptw. classification     NaN  avg. spearman  0.6360     5
# 25   ptw. classification   bayes  avg. spearman  0.6463     1
# 26   ptw. classification   bayes  avg. spearman  0.6021     2
# 27   ptw. classification   bayes  avg. spearman  0.6093     3
# 28   ptw. classification   bayes  avg. spearman  0.6285     4
# 29   ptw. classification   bayes  avg. spearman  0.6012     5
# 30  ptw. ord. regression     NaN  avg. spearman  0.6389     1
# 31  ptw. ord. regression     NaN  avg. spearman  0.6491     2
# 32  ptw. ord. regression     NaN  avg. spearman  0.6231     3
# 33  ptw. ord. regression     NaN  avg. spearman  0.6637     4
# 34  ptw. ord. regression     NaN  avg. spearman  0.6365     5
# 35  ptw. ord. regression   bayes  avg. spearman  0.6598     1
# 36  ptw. ord. regression   bayes  avg. spearman  0.6491     2
# 37  ptw. ord. regression   bayes  avg. spearman  0.6123     3
# 38  ptw. ord. regression   bayes  avg. spearman  0.6552     4
# 39  ptw. ord. regression   bayes  avg. spearman  0.6520     5
# 40    pw. classification     NaN  avg. spearman  0.7178     1
# 41    pw. classification     NaN  avg. spearman  0.7219     2
# 42    pw. classification     NaN  avg. spearman  0.7204     3
# 43    pw. classification     NaN  avg. spearman  0.7164     4
# 44    pw. classification     NaN  avg. spearman  0.7218     5
# 45    pw. classification  optuna  avg. spearman  0.7226     1
# 46    pw. classification  optuna  avg. spearman  0.7238     2
# 47    pw. classification  optuna  avg. spearman  0.7116     3
# 48    pw. classification  optuna  avg. spearman  0.7320     4
# 49    pw. classification  optuna  avg. spearman  0.7247     5
# 50      lstw. regression     NaN  avg. spearman  0.7693     1
# 51      lstw. regression     NaN  avg. spearman  0.7382     2
# 52      lstw. regression     NaN  avg. spearman  0.7188     3
# 53      lstw. regression     NaN  avg. spearman  0.7493     4
# 54      lstw. regression     NaN  avg. spearman  0.7273     5
# 55      lstw. regression   bayes  avg. spearman  0.7223     1
# 56      lstw. regression   bayes  avg. spearman  0.6940     2
# 57      lstw. regression   bayes  avg. spearman  0.7307     3
# 58      lstw. regression   bayes  avg. spearman  0.7466     4
# 59      lstw. regression   bayes  avg. spearman  0.7167     5
# 60  lstw. neural network     NaN  avg. spearman  0.1504     1
# 61  lstw. neural network     NaN  avg. spearman  0.1739     2
# 62  lstw. neural network     NaN  avg. spearman  0.1246     3
# 63  lstw. neural network     NaN  avg. spearman  0.1511     4
# 64  lstw. neural network     NaN  avg. spearman  0.1319     5
# 65  lstw. neural network     NaN           ndcg  0.6524     1
# 66  lstw. neural network     NaN           ndcg  0.6985     2
# 67  lstw. neural network     NaN           ndcg  0.6875     3
# 68  lstw. neural network     NaN           ndcg  0.6890     4
# 69  lstw. neural network     NaN           ndcg  0.6790     5

# %%
def get_data(data, approach, metric=['avg. spearman']):
    conditions = pd.Series(np.repeat(True, len(data)))
    conditions = conditions & (data['approach'] == np.full(len(data), approach)) if approach is not None else conditions
    conditions = conditions & (data['metric'] == np.full(len(data), metric)) if metric is not None else conditions
    return data[conditions]

def plot(data, name):
    # Filter data based on unique x or y values
    
    data = data.groupby('category').filter(lambda x: x['approach'].nunique() == len(data['approach'].value_counts()))
    sns.barplot(x=data['approach'], y=data['score'], hue=data['category'])
    plt.title('performance')
    plt.ylabel('avg. spearman')
    plt.xlabel('')
    if len(data['approach'].value_counts()) >= 3:
        plt.xticks(rotation=18)
    plt.legend(loc='lower left')
    plt.savefig(name + '_comparison.svg', bbox_inches='tight')
    plt.show()
    
def set_category(data, grouping, categories):
    def append_category(row):
        group = tuple(row[grouping].values[0])
        row['category'] = categories[group]
        return row
    grouped = data.groupby(grouping, dropna=False)
    return grouped.apply(append_category).reset_index(drop=True)

# %%
approaches = [
    'regression',
    'ptw. regression',
    'ptw. classification',
    'ptw. ord. regression',
    'pw. classification',
    'lstw. regression',
    'lstw. neural network',
]

data_by_approach = {}
for approach in approaches:
    data_by_approach[approach] = get_data(data, approach, metric=['avg. spearman'])
    
for approach in approaches:
    data_by_approach[approach] = set_category(data_by_approach[approach], ['tuning'], {
        (np.nan,): 'default',
        ('bayes',): 'tuned',
        ('optuna',): 'tuned'
    })

data_categorized = pd.concat(data_by_approach.values())

# %%
plot(pd.concat([
    data_by_approach[approach] for approach in [
        'regression',
        'ptw. regression',
        'ptw. classification',
        'ptw. ord. regression',
    ]
]), 'regre_ptwregre_ptwcls_ptword')

plot(pd.concat([
    data_by_approach[approach] for approach in [
        'regression',
        'ptw. regression',
        'ptw. classification',
        'ptw. ord. regression',
        'pw. classification'
    ]
]), 'regre_ptwregre_ptwcls_ptword_pwcls')

plot(pd.concat([
    data_by_approach[approach] for approach in [
        'ptw. regression',
        'pw. classification'
    ]
]), 'ptwregre_pwcls')

plot(pd.concat([
    data_by_approach[approach] for approach in [
        'regression',
        'ptw. regression',
        'ptw. classification',
        'ptw. ord. regression',
        'pw. classification',
        'lstw. regression',
    ]
]), 'regre_ptwregre_ptwcls_ptword_pwcls_lstwregre')

plot(pd.concat([
    data_by_approach[approach] for approach in [
        'ptw. regression',
        'pw. classification',
        'lstw. regression'
    ]
]), 'ptwregre_pwcls_lstwregre')

plot(pd.concat([
    data_by_approach[approach] for approach in [
        'regression',
        'ptw. regression',
        'ptw. classification',
        'ptw. ord. regression',
        'pw. classification',
        'lstw. regression',
        'lstw. neural network',
    ]
]), 'regre_ptwregre_ptwcls_ptword_pwcls_lstwregre_lstwnn')

# %%
data = data.where(data['approach'] == 'lstw. neural network')
sns.barplot(x=data['approach'], y=data['score'], hue=data['metric'])
plt.title('performance')
plt.ylabel('score')
plt.xlabel('')
if len(data['approach'].value_counts()) >= 3:
    plt.xticks(rotation=18)
plt.legend(loc='lower left')
plt.savefig('lstwnn_comparison.svg', bbox_inches='tight')
plt.show()
